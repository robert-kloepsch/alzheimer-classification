# %%
#load all packages

# base packages
import keras
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2

# tensorflow and keras
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.utils import image_dataset_from_directory
from keras import metrics

# sklearn
from sklearn.utils import shuffle
from sklearn.metrics import recall_score, precision_score, confusion_matrix

# self-build procedures
from roc_multiclass import roc_multiclass
from precision_recall_multiclass import precision_recall_multiclass
from load_oasis_set import load_oasis_set
from load_oasis_set_win import load_oasis_set_win
from DataGenerator import DataGenerator

# model architectures
from cnn_backbone import base_model

# %% [markdown]
# ### Load Train Data and oversample

# %%
# load dataset from drive
#PATH = "/Users/josealbertodiazsalas/Documents/Alzheimer_s Dataset/train"
PATH = "F:\\MRI_class\\data\\Alzheimer_s Dataset_30percentVal\\train"
IMAGE_SIZE = (208, 176)
train_ds = image_dataset_from_directory(
                                        PATH, 
                                        seed=10, 
                                        shuffle=False,              #<---
                                        image_size=IMAGE_SIZE, 
                                        batch_size=32
                                        )
                                        
# one hot encode the labels to fit into the cnn layers
train_ds = train_ds.map(lambda x, y: (x, tf.one_hot(y, depth=3)))
# Out:
# Found 3040 files belonging to 3 classes.

# %% [markdown]
# ### Deconstuct Train Dataset and Prepare for Oversampling

# %%
# seperation of validation set
# !!! these sets are not shuffled !!!

train_big = train_ds
X1_train_big = []
y1_train_big = []
X2_train_big = []
y2_train_big = []
X3_train_big = []
y3_train_big = []


for img, label in train_ds.unbatch():
    if label.numpy()[0] == 1:
        X1_train_big.append(img.numpy())
        y1_train_big.append(label.numpy())

    if label.numpy()[1] == 1:
        X2_train_big.append(img.numpy())
        y2_train_big.append(label.numpy())

    if label.numpy()[2] == 1:
        X3_train_big.append(img.numpy())
        y3_train_big.append(label.numpy())

# %% [markdown]
# ### Oversampling
# Fill classes to match class 0 (Healthy)

# %%
# create dataset for class 1 -NO oversampling- (healthy)
X1_train_big = np.array(X1_train_big)
y1_train_big = np.array(y1_train_big)

# %%
# oversampling for class 2 (very mild)

randomPicksIdx = [np.random.choice(len(X2_train_big)) for i in range(len(X1_train_big) - len(X2_train_big))]

for i in randomPicksIdx:
    X2_train_big.append(X2_train_big[i])
    y2_train_big.append(y2_train_big[i])

X2_train_big = np.array(X2_train_big)
y2_train_big = np.array(y2_train_big)

# %%
# oversampling for class 3 (mild)
randomPicksIdx = [np.random.choice(len(X3_train_big)) for i in range(len(X1_train_big) - len(X3_train_big))]            # images are randomly picked

for i in randomPicksIdx:
    X3_train_big.append(X3_train_big[i])
    y3_train_big.append(y3_train_big[i])

X3_train_big = np.array(X3_train_big)
y3_train_big = np.array(y3_train_big)

# %% [markdown]
# ### Construct full Dataset Tensor for Training

# %%
# combine all data sets
X_train_fullset = np.concatenate((X1_train_big,X2_train_big,X3_train_big), axis=0)
y_train_fullset = np.concatenate((y1_train_big,y2_train_big,y3_train_big), axis=0)

# %%
# shuffle the whole set
X_train_temp, y_train_temp = shuffle(X_train_fullset, y_train_fullset, random_state=10)

# %%
# finally create tensor dataset
data_generator = DataGenerator(X_train_temp, y_train_temp, batch_size = 32)

train_fullTensor = tf.data.Dataset.from_generator(
                                            data_generator,
                                            output_signature=(tf.TensorSpec(shape=(None, 208, 176, 3), dtype=tf.float32), tf.TensorSpec(shape=(None, 3), dtype=tf.float32))
                                            )

# %% [markdown]
# ### Load Validation Set

# %%
# load validation dataset from drive
# set for training
#PATH = "/Users/josealbertodiazsalas/Documents/Alzheimer_s Dataset/train"
PATH = "F:\\MRI_class\\data\\Alzheimer_s Dataset_30percentVal\\validation"
IMAGE_SIZE = (208, 176)
val_ds = image_dataset_from_directory(
                                        PATH, 
                                        seed=10, 
                                        shuffle=True, 
                                        image_size=IMAGE_SIZE, 
                                        batch_size=32
                                        )

# one hot encode the labels to fit into the cnn layers
val_fullTensor = val_ds.map(lambda x, y: (x, tf.one_hot(y, depth=3)))
# Out:
# Found 2029 files belonging to 3 classes.

# %% [markdown]
# ### Check Images for Integrity

# %%
# plot some example images from loaded set
plt.figure(figsize=(10, 10))
for images, labels in train_fullTensor.take(1):
  for i in range(3):
    ax = plt.subplot(1, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"), cmap="gray")
    plt.title([labels[i].numpy()][0])
    plt.axis("off")
# Out:
# f:\env\lib\site-packages\matplotlib\text.py:1223: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %% [markdown]
# # Creating CNN Architecture
# ### First Creating Augmentation Module

# %%
with tf.device("/gpu:0"):
    data_augmentation = keras.Sequential([
        layers.InputLayer(input_shape=(208, 176, 3)),
        layers.Lambda(lambda x: tf.image.resize(x, (208, 176))),
        layers.Lambda(lambda x: tf.image.random_contrast(x,0.6,1)),
        layers.Lambda(lambda x: tf.image.random_brightness(x,0.3)),             #<--- delta value depends on image range. if 0-1 delta should be between 0-1. if 0-255 delta should be between 0-255
        layers.RandomRotation(0.01),
        layers.RandomFlip(mode="horizontal"),    
        layers.RandomZoom(0.03),
        #layers.RandomBrightness((0.2), value_range=(0,255)),
        #layers.Resizing(208, 176),
        #layers.RandomContrast((0.2))
])

# %% [markdown]
# ### Check Images for proper Augmentation

# %%
with tf.device("/gpu:0"):
    plt.figure(figsize=(10, 10))
    for images, labels in train_fullTensor.take(1):
        for i in range(3):
            ax = plt.subplot(1, 3, i + 1)
            img = data_augmentation(images/255)             # divided by 255 (normalization) since augmentation depends on normalization which is 
            plt.imshow(img[i].numpy(), cmap="gray")         # a specific layer in the CNN and not part of augmentation
            plt.title([labels[i].numpy()][0])
            plt.axis("off")
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ### Building the complete CNN
# #### Construct InceptionV3 Backbone
# Custom model architecture using classification layers based on similar projects + ResNet50 as backbone <br>
# Customized layers used -> https://www.kaggle.com/code/gauravrajpal/alzheimer-s-classification-densenet201-auc-86-56

# %%
# Defining both base and final model architecture
b_model = base_model(MODEL='InceptionV3', freeze_layers=False)
b_model.summary()
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 208, 176, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 103, 87, 32)  864         ['input_2[0][0]']
#
#  batch_normalization (BatchNorm  (None, 103, 87, 32)  96         ['conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 103, 87, 32)  0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 101, 85, 32)  9216        ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 101, 85, 32)  96         ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 101, 85, 32)  0           ['batch_normalization_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 101, 85, 64)  18432       ['activation_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 101, 85, 64)  192        ['conv2d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 101, 85, 64)  0           ['batch_normalization_2[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 50, 42, 64)   0           ['activation_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 50, 42, 80)   5120        ['max_pooling2d[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 50, 42, 80)  240         ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 50, 42, 80)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 48, 40, 192)  138240      ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 48, 40, 192)  576        ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 48, 40, 192)  0           ['batch_normalization_4[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 23, 19, 192)  0          ['activation_4[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 23, 19, 64)   12288       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 23, 19, 64)  192         ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 23, 19, 64)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 23, 19, 48)   9216        ['max_pooling2d_1[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 23, 19, 96)   55296       ['activation_8[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 23, 19, 48)  144         ['conv2d_6[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 23, 19, 96)  288         ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 23, 19, 48)   0           ['batch_normalization_6[0][0]']
#
#  activation_9 (Activation)      (None, 23, 19, 96)   0           ['batch_normalization_9[0][0]']
#
#  average_pooling2d (AveragePool  (None, 23, 19, 192)  0          ['max_pooling2d_1[0][0]']
#  ing2D)
#
#  conv2d_5 (Conv2D)              (None, 23, 19, 64)   12288       ['max_pooling2d_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 23, 19, 64)   76800       ['activation_6[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 23, 19, 96)   82944       ['activation_9[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 23, 19, 32)   6144        ['average_pooling2d[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 23, 19, 64)  192         ['conv2d_5[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 23, 19, 64)  192         ['conv2d_7[0][0]']
#  rmalization)
#
#  batch_normalization_10 (BatchN  (None, 23, 19, 96)  288         ['conv2d_10[0][0]']
#  ormalization)
#
#  batch_normalization_11 (BatchN  (None, 23, 19, 32)  96          ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_5 (Activation)      (None, 23, 19, 64)   0           ['batch_normalization_5[0][0]']
#
#  activation_7 (Activation)      (None, 23, 19, 64)   0           ['batch_normalization_7[0][0]']
#
#  activation_10 (Activation)     (None, 23, 19, 96)   0           ['batch_normalization_10[0][0]']
#
#  activation_11 (Activation)     (None, 23, 19, 32)   0           ['batch_normalization_11[0][0]']
#
#  mixed0 (Concatenate)           (None, 23, 19, 256)  0           ['activation_5[0][0]',
#                                                                   'activation_7[0][0]',
#                                                                   'activation_10[0][0]',
#                                                                   'activation_11[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 23, 19, 64)   16384       ['mixed0[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 23, 19, 64)  192         ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 23, 19, 64)   0           ['batch_normalization_15[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 23, 19, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 23, 19, 96)   55296       ['activation_15[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 23, 19, 48)  144         ['conv2d_13[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 23, 19, 96)  288         ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 23, 19, 48)   0           ['batch_normalization_13[0][0]']
#
#  activation_16 (Activation)     (None, 23, 19, 96)   0           ['batch_normalization_16[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 23, 19, 256)  0          ['mixed0[0][0]']
#  oling2D)
#
#  conv2d_12 (Conv2D)             (None, 23, 19, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 23, 19, 64)   76800       ['activation_13[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 23, 19, 96)   82944       ['activation_16[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 23, 19, 64)   16384       ['average_pooling2d_1[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 23, 19, 64)  192         ['conv2d_12[0][0]']
#  ormalization)
#
#  batch_normalization_14 (BatchN  (None, 23, 19, 64)  192         ['conv2d_14[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 23, 19, 96)  288         ['conv2d_17[0][0]']
#  ormalization)
#
#  batch_normalization_18 (BatchN  (None, 23, 19, 64)  192         ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 23, 19, 64)   0           ['batch_normalization_12[0][0]']
#
#  activation_14 (Activation)     (None, 23, 19, 64)   0           ['batch_normalization_14[0][0]']
#
#  activation_17 (Activation)     (None, 23, 19, 96)   0           ['batch_normalization_17[0][0]']
#
#  activation_18 (Activation)     (None, 23, 19, 64)   0           ['batch_normalization_18[0][0]']
#
#  mixed1 (Concatenate)           (None, 23, 19, 288)  0           ['activation_12[0][0]',
#                                                                   'activation_14[0][0]',
#                                                                   'activation_17[0][0]',
#                                                                   'activation_18[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 23, 19, 64)   18432       ['mixed1[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 23, 19, 64)  192         ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 23, 19, 64)   0           ['batch_normalization_22[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 23, 19, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 23, 19, 96)   55296       ['activation_22[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 23, 19, 48)  144         ['conv2d_20[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 23, 19, 96)  288         ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 23, 19, 48)   0           ['batch_normalization_20[0][0]']
#
#  activation_23 (Activation)     (None, 23, 19, 96)   0           ['batch_normalization_23[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 23, 19, 288)  0          ['mixed1[0][0]']
#  oling2D)
#
#  conv2d_19 (Conv2D)             (None, 23, 19, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 23, 19, 64)   76800       ['activation_20[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 23, 19, 96)   82944       ['activation_23[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 23, 19, 64)   18432       ['average_pooling2d_2[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 23, 19, 64)  192         ['conv2d_19[0][0]']
#  ormalization)
#
#  batch_normalization_21 (BatchN  (None, 23, 19, 64)  192         ['conv2d_21[0][0]']
#  ormalization)
#
#  batch_normalization_24 (BatchN  (None, 23, 19, 96)  288         ['conv2d_24[0][0]']
#  ormalization)
#
#  batch_normalization_25 (BatchN  (None, 23, 19, 64)  192         ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 23, 19, 64)   0           ['batch_normalization_19[0][0]']
#
#  activation_21 (Activation)     (None, 23, 19, 64)   0           ['batch_normalization_21[0][0]']
#
#  activation_24 (Activation)     (None, 23, 19, 96)   0           ['batch_normalization_24[0][0]']
#
#  activation_25 (Activation)     (None, 23, 19, 64)   0           ['batch_normalization_25[0][0]']
#
#  mixed2 (Concatenate)           (None, 23, 19, 288)  0           ['activation_19[0][0]',
#                                                                   'activation_21[0][0]',
#                                                                   'activation_24[0][0]',
#                                                                   'activation_25[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 23, 19, 64)   18432       ['mixed2[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 23, 19, 64)  192         ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 23, 19, 64)   0           ['batch_normalization_27[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 23, 19, 96)   55296       ['activation_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 23, 19, 96)  288         ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 23, 19, 96)   0           ['batch_normalization_28[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 11, 9, 384)   995328      ['mixed2[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 11, 9, 96)    82944       ['activation_28[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 11, 9, 384)  1152        ['conv2d_26[0][0]']
#  ormalization)
#
#  batch_normalization_29 (BatchN  (None, 11, 9, 96)   288         ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 11, 9, 384)   0           ['batch_normalization_26[0][0]']
#
#  activation_29 (Activation)     (None, 11, 9, 96)    0           ['batch_normalization_29[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 11, 9, 288)  0           ['mixed2[0][0]']
#
#  mixed3 (Concatenate)           (None, 11, 9, 768)   0           ['activation_26[0][0]',
#                                                                   'activation_29[0][0]',
#                                                                   'max_pooling2d_2[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 11, 9, 128)   98304       ['mixed3[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 11, 9, 128)  384         ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 11, 9, 128)   0           ['batch_normalization_34[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 11, 9, 128)   114688      ['activation_34[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 11, 9, 128)  384         ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 11, 9, 128)   0           ['batch_normalization_35[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 11, 9, 128)   98304       ['mixed3[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 11, 9, 128)   114688      ['activation_35[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 11, 9, 128)  384         ['conv2d_31[0][0]']
#  ormalization)
#
#  batch_normalization_36 (BatchN  (None, 11, 9, 128)  384         ['conv2d_36[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 11, 9, 128)   0           ['batch_normalization_31[0][0]']
#
#  activation_36 (Activation)     (None, 11, 9, 128)   0           ['batch_normalization_36[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 11, 9, 128)   114688      ['activation_31[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 11, 9, 128)   114688      ['activation_36[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 11, 9, 128)  384         ['conv2d_32[0][0]']
#  ormalization)
#
#  batch_normalization_37 (BatchN  (None, 11, 9, 128)  384         ['conv2d_37[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 11, 9, 128)   0           ['batch_normalization_32[0][0]']
#
#  activation_37 (Activation)     (None, 11, 9, 128)   0           ['batch_normalization_37[0][0]']
#
#  average_pooling2d_3 (AveragePo  (None, 11, 9, 768)  0           ['mixed3[0][0]']
#  oling2D)
#
#  conv2d_30 (Conv2D)             (None, 11, 9, 192)   147456      ['mixed3[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 11, 9, 192)   172032      ['activation_32[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 11, 9, 192)   172032      ['activation_37[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 11, 9, 192)   147456      ['average_pooling2d_3[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 11, 9, 192)  576         ['conv2d_30[0][0]']
#  ormalization)
#
#  batch_normalization_33 (BatchN  (None, 11, 9, 192)  576         ['conv2d_33[0][0]']
#  ormalization)
#
#  batch_normalization_38 (BatchN  (None, 11, 9, 192)  576         ['conv2d_38[0][0]']
#  ormalization)
#
#  batch_normalization_39 (BatchN  (None, 11, 9, 192)  576         ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 11, 9, 192)   0           ['batch_normalization_30[0][0]']
#
#  activation_33 (Activation)     (None, 11, 9, 192)   0           ['batch_normalization_33[0][0]']
#
#  activation_38 (Activation)     (None, 11, 9, 192)   0           ['batch_normalization_38[0][0]']
#
#  activation_39 (Activation)     (None, 11, 9, 192)   0           ['batch_normalization_39[0][0]']
#
#  mixed4 (Concatenate)           (None, 11, 9, 768)   0           ['activation_30[0][0]',
#                                                                   'activation_33[0][0]',
#                                                                   'activation_38[0][0]',
#                                                                   'activation_39[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 11, 9, 160)   122880      ['mixed4[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 11, 9, 160)  480         ['conv2d_44[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 11, 9, 160)   0           ['batch_normalization_44[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 11, 9, 160)   179200      ['activation_44[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 11, 9, 160)  480         ['conv2d_45[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 11, 9, 160)   0           ['batch_normalization_45[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 11, 9, 160)   122880      ['mixed4[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 11, 9, 160)   179200      ['activation_45[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 11, 9, 160)  480         ['conv2d_41[0][0]']
#  ormalization)
#
#  batch_normalization_46 (BatchN  (None, 11, 9, 160)  480         ['conv2d_46[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 11, 9, 160)   0           ['batch_normalization_41[0][0]']
#
#  activation_46 (Activation)     (None, 11, 9, 160)   0           ['batch_normalization_46[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 11, 9, 160)   179200      ['activation_41[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 11, 9, 160)   179200      ['activation_46[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 11, 9, 160)  480         ['conv2d_42[0][0]']
#  ormalization)
#
#  batch_normalization_47 (BatchN  (None, 11, 9, 160)  480         ['conv2d_47[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 11, 9, 160)   0           ['batch_normalization_42[0][0]']
#
#  activation_47 (Activation)     (None, 11, 9, 160)   0           ['batch_normalization_47[0][0]']
#
#  average_pooling2d_4 (AveragePo  (None, 11, 9, 768)  0           ['mixed4[0][0]']
#  oling2D)
#
#  conv2d_40 (Conv2D)             (None, 11, 9, 192)   147456      ['mixed4[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 11, 9, 192)   215040      ['activation_42[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 11, 9, 192)   215040      ['activation_47[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 11, 9, 192)   147456      ['average_pooling2d_4[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 11, 9, 192)  576         ['conv2d_40[0][0]']
#  ormalization)
#
#  batch_normalization_43 (BatchN  (None, 11, 9, 192)  576         ['conv2d_43[0][0]']
#  ormalization)
#
#  batch_normalization_48 (BatchN  (None, 11, 9, 192)  576         ['conv2d_48[0][0]']
#  ormalization)
#
#  batch_normalization_49 (BatchN  (None, 11, 9, 192)  576         ['conv2d_49[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 11, 9, 192)   0           ['batch_normalization_40[0][0]']
#
#  activation_43 (Activation)     (None, 11, 9, 192)   0           ['batch_normalization_43[0][0]']
#
#  activation_48 (Activation)     (None, 11, 9, 192)   0           ['batch_normalization_48[0][0]']
#
#  activation_49 (Activation)     (None, 11, 9, 192)   0           ['batch_normalization_49[0][0]']
#
#  mixed5 (Concatenate)           (None, 11, 9, 768)   0           ['activation_40[0][0]',
#                                                                   'activation_43[0][0]',
#                                                                   'activation_48[0][0]',
#                                                                   'activation_49[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 11, 9, 160)   122880      ['mixed5[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 11, 9, 160)  480         ['conv2d_54[0][0]']
#  ormalization)
#
#  activation_54 (Activation)     (None, 11, 9, 160)   0           ['batch_normalization_54[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 11, 9, 160)   179200      ['activation_54[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 11, 9, 160)  480         ['conv2d_55[0][0]']
#  ormalization)
#
#  activation_55 (Activation)     (None, 11, 9, 160)   0           ['batch_normalization_55[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 11, 9, 160)   122880      ['mixed5[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 11, 9, 160)   179200      ['activation_55[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 11, 9, 160)  480         ['conv2d_51[0][0]']
#  ormalization)
#
#  batch_normalization_56 (BatchN  (None, 11, 9, 160)  480         ['conv2d_56[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 11, 9, 160)   0           ['batch_normalization_51[0][0]']
#
#  activation_56 (Activation)     (None, 11, 9, 160)   0           ['batch_normalization_56[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 11, 9, 160)   179200      ['activation_51[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 11, 9, 160)   179200      ['activation_56[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 11, 9, 160)  480         ['conv2d_52[0][0]']
#  ormalization)
#
#  batch_normalization_57 (BatchN  (None, 11, 9, 160)  480         ['conv2d_57[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 11, 9, 160)   0           ['batch_normalization_52[0][0]']
#
#  activation_57 (Activation)     (None, 11, 9, 160)   0           ['batch_normalization_57[0][0]']
#
#  average_pooling2d_5 (AveragePo  (None, 11, 9, 768)  0           ['mixed5[0][0]']
#  oling2D)
#
#  conv2d_50 (Conv2D)             (None, 11, 9, 192)   147456      ['mixed5[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 11, 9, 192)   215040      ['activation_52[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 11, 9, 192)   215040      ['activation_57[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 11, 9, 192)   147456      ['average_pooling2d_5[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 11, 9, 192)  576         ['conv2d_50[0][0]']
#  ormalization)
#
#  batch_normalization_53 (BatchN  (None, 11, 9, 192)  576         ['conv2d_53[0][0]']
#  ormalization)
#
#  batch_normalization_58 (BatchN  (None, 11, 9, 192)  576         ['conv2d_58[0][0]']
#  ormalization)
#
#  batch_normalization_59 (BatchN  (None, 11, 9, 192)  576         ['conv2d_59[0][0]']
#  ormalization)
#
#  activation_50 (Activation)     (None, 11, 9, 192)   0           ['batch_normalization_50[0][0]']
#
#  activation_53 (Activation)     (None, 11, 9, 192)   0           ['batch_normalization_53[0][0]']
#
#  activation_58 (Activation)     (None, 11, 9, 192)   0           ['batch_normalization_58[0][0]']
#
#  activation_59 (Activation)     (None, 11, 9, 192)   0           ['batch_normalization_59[0][0]']
#
#  mixed6 (Concatenate)           (None, 11, 9, 768)   0           ['activation_50[0][0]',
#                                                                   'activation_53[0][0]',
#                                                                   'activation_58[0][0]',
#                                                                   'activation_59[0][0]']
#
# ...
#  mixed8 (Concatenate)           (None, 5, 4, 1280)   0           ['activation_71[0][0]',
#                                                                   'activation_75[0][0]',
#                                                                   'max_pooling2d_3[0][0]']
#
#  conv2d_80 (Conv2D)             (None, 5, 4, 448)    573440      ['mixed8[0][0]']
#
#  batch_normalization_80 (BatchN  (None, 5, 4, 448)   1344        ['conv2d_80[0][0]']
#  ormalization)
#
#  activation_80 (Activation)     (None, 5, 4, 448)    0           ['batch_normalization_80[0][0]']
#
#  conv2d_77 (Conv2D)             (None, 5, 4, 384)    491520      ['mixed8[0][0]']
#
#  conv2d_81 (Conv2D)             (None, 5, 4, 384)    1548288     ['activation_80[0][0]']
#
#  batch_normalization_77 (BatchN  (None, 5, 4, 384)   1152        ['conv2d_77[0][0]']
#  ormalization)
#
#  batch_normalization_81 (BatchN  (None, 5, 4, 384)   1152        ['conv2d_81[0][0]']
#  ormalization)
#
#  activation_77 (Activation)     (None, 5, 4, 384)    0           ['batch_normalization_77[0][0]']
#
#  activation_81 (Activation)     (None, 5, 4, 384)    0           ['batch_normalization_81[0][0]']
#
#  conv2d_78 (Conv2D)             (None, 5, 4, 384)    442368      ['activation_77[0][0]']
#
#  conv2d_79 (Conv2D)             (None, 5, 4, 384)    442368      ['activation_77[0][0]']
#
#  conv2d_82 (Conv2D)             (None, 5, 4, 384)    442368      ['activation_81[0][0]']
#
#  conv2d_83 (Conv2D)             (None, 5, 4, 384)    442368      ['activation_81[0][0]']
#
#  average_pooling2d_7 (AveragePo  (None, 5, 4, 1280)  0           ['mixed8[0][0]']
#  oling2D)
#
#  conv2d_76 (Conv2D)             (None, 5, 4, 320)    409600      ['mixed8[0][0]']
#
#  batch_normalization_78 (BatchN  (None, 5, 4, 384)   1152        ['conv2d_78[0][0]']
#  ormalization)
#
#  batch_normalization_79 (BatchN  (None, 5, 4, 384)   1152        ['conv2d_79[0][0]']
#  ormalization)
#
#  batch_normalization_82 (BatchN  (None, 5, 4, 384)   1152        ['conv2d_82[0][0]']
#  ormalization)
#
#  batch_normalization_83 (BatchN  (None, 5, 4, 384)   1152        ['conv2d_83[0][0]']
#  ormalization)
#
#  conv2d_84 (Conv2D)             (None, 5, 4, 192)    245760      ['average_pooling2d_7[0][0]']
#
#  batch_normalization_76 (BatchN  (None, 5, 4, 320)   960         ['conv2d_76[0][0]']
#  ormalization)
#
#  activation_78 (Activation)     (None, 5, 4, 384)    0           ['batch_normalization_78[0][0]']
#
#  activation_79 (Activation)     (None, 5, 4, 384)    0           ['batch_normalization_79[0][0]']
#
#  activation_82 (Activation)     (None, 5, 4, 384)    0           ['batch_normalization_82[0][0]']
#
#  activation_83 (Activation)     (None, 5, 4, 384)    0           ['batch_normalization_83[0][0]']
#
#  batch_normalization_84 (BatchN  (None, 5, 4, 192)   576         ['conv2d_84[0][0]']
#  ormalization)
#
#  activation_76 (Activation)     (None, 5, 4, 320)    0           ['batch_normalization_76[0][0]']
#
#  mixed9_0 (Concatenate)         (None, 5, 4, 768)    0           ['activation_78[0][0]',
#                                                                   'activation_79[0][0]']
#
#  concatenate (Concatenate)      (None, 5, 4, 768)    0           ['activation_82[0][0]',
#                                                                   'activation_83[0][0]']
#
#  activation_84 (Activation)     (None, 5, 4, 192)    0           ['batch_normalization_84[0][0]']
#
#  mixed9 (Concatenate)           (None, 5, 4, 2048)   0           ['activation_76[0][0]',
#                                                                   'mixed9_0[0][0]',
#                                                                   'concatenate[0][0]',
#                                                                   'activation_84[0][0]']
#
#  conv2d_89 (Conv2D)             (None, 5, 4, 448)    917504      ['mixed9[0][0]']
#
#  batch_normalization_89 (BatchN  (None, 5, 4, 448)   1344        ['conv2d_89[0][0]']
#  ormalization)
#
#  activation_89 (Activation)     (None, 5, 4, 448)    0           ['batch_normalization_89[0][0]']
#
#  conv2d_86 (Conv2D)             (None, 5, 4, 384)    786432      ['mixed9[0][0]']
#
#  conv2d_90 (Conv2D)             (None, 5, 4, 384)    1548288     ['activation_89[0][0]']
#
#  batch_normalization_86 (BatchN  (None, 5, 4, 384)   1152        ['conv2d_86[0][0]']
#  ormalization)
#
#  batch_normalization_90 (BatchN  (None, 5, 4, 384)   1152        ['conv2d_90[0][0]']
#  ormalization)
#
#  activation_86 (Activation)     (None, 5, 4, 384)    0           ['batch_normalization_86[0][0]']
#
#  activation_90 (Activation)     (None, 5, 4, 384)    0           ['batch_normalization_90[0][0]']
#
#  conv2d_87 (Conv2D)             (None, 5, 4, 384)    442368      ['activation_86[0][0]']
#
#  conv2d_88 (Conv2D)             (None, 5, 4, 384)    442368      ['activation_86[0][0]']
#
#  conv2d_91 (Conv2D)             (None, 5, 4, 384)    442368      ['activation_90[0][0]']
#
#  conv2d_92 (Conv2D)             (None, 5, 4, 384)    442368      ['activation_90[0][0]']
#
#  average_pooling2d_8 (AveragePo  (None, 5, 4, 2048)  0           ['mixed9[0][0]']
#  oling2D)
#
#  conv2d_85 (Conv2D)             (None, 5, 4, 320)    655360      ['mixed9[0][0]']
#
#  batch_normalization_87 (BatchN  (None, 5, 4, 384)   1152        ['conv2d_87[0][0]']
#  ormalization)
#
#  batch_normalization_88 (BatchN  (None, 5, 4, 384)   1152        ['conv2d_88[0][0]']
#  ormalization)
#
#  batch_normalization_91 (BatchN  (None, 5, 4, 384)   1152        ['conv2d_91[0][0]']
#  ormalization)
#
#  batch_normalization_92 (BatchN  (None, 5, 4, 384)   1152        ['conv2d_92[0][0]']
#  ormalization)
#
#  conv2d_93 (Conv2D)             (None, 5, 4, 192)    393216      ['average_pooling2d_8[0][0]']
#
#  batch_normalization_85 (BatchN  (None, 5, 4, 320)   960         ['conv2d_85[0][0]']
#  ormalization)
#
#  activation_87 (Activation)     (None, 5, 4, 384)    0           ['batch_normalization_87[0][0]']
#
#  activation_88 (Activation)     (None, 5, 4, 384)    0           ['batch_normalization_88[0][0]']
#
#  activation_91 (Activation)     (None, 5, 4, 384)    0           ['batch_normalization_91[0][0]']
#
#  activation_92 (Activation)     (None, 5, 4, 384)    0           ['batch_normalization_92[0][0]']
#
#  batch_normalization_93 (BatchN  (None, 5, 4, 192)   576         ['conv2d_93[0][0]']
#  ormalization)
#
#  activation_85 (Activation)     (None, 5, 4, 320)    0           ['batch_normalization_85[0][0]']
#
#  mixed9_1 (Concatenate)         (None, 5, 4, 768)    0           ['activation_87[0][0]',
#                                                                   'activation_88[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 5, 4, 768)    0           ['activation_91[0][0]',
#                                                                   'activation_92[0][0]']
#
#  activation_93 (Activation)     (None, 5, 4, 192)    0           ['batch_normalization_93[0][0]']
#
#  mixed10 (Concatenate)          (None, 5, 4, 2048)   0           ['activation_85[0][0]',
#                                                                   'mixed9_1[0][0]',
#                                                                   'concatenate_1[0][0]',
#                                                                   'activation_93[0][0]']
#
# ==================================================================================================
# Total params: 21,802,784
# Trainable params: 21,768,352
# Non-trainable params: 34,432
# __________________________________________________________________________________________________

# %% [markdown]
# ### Combine Backbone with Augmentation and Dense Layers

# %%
# Definition conv and classification layers
model = models.Sequential()
model.add(layers.InputLayer(input_shape=(208, 176, 3)))
model.add(layers.Rescaling(1.0/255))
model.add(data_augmentation)
model.add(b_model)
model.add(layers.Flatten())
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dropout(0.3))
model.add(layers.Dense(3, activation="softmax"))

# Print only Conv and Pooling layer from model architecture
model.build()
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 208, 176, 3)       0
#
#  sequential (Sequential)     (None, 208, 176, 3)       0
#
#  inception_v3 (Functional)   (None, 5, 4, 2048)        21802784
#
#  flatten (Flatten)           (None, 40960)             0
#
#  dense (Dense)               (None, 512)               20972032
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_2 (Dense)             (None, 3)                 1539
#
# =================================================================
# Total params: 43,039,011
# Trainable params: 43,004,579
# Non-trainable params: 34,432
# _________________________________________________________________

# %% [markdown]
# ### Defining the Optimizer

# %%
# Defining optimizer and learning rate
lr_schedule = tf.keras.optimizers.schedules.InverseTimeDecay(
    0.00001,
    decay_steps=10000,
    decay_rate=1,
    staircase=False)
optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule, name='Adam')

# %% [markdown]
# ### Compile the CNN Architecture

# %%
# Freeze the the behavior of that model. If any trainable value changes, compile() must be called again
keras.backend.clear_session()
model.compile(optimizer=optimizer,
    loss="CategoricalCrossentropy",
    metrics=[metrics.Precision(), metrics.Recall()])

# %% [markdown]
# ### Train the Model
# You can chose the save the model iterativly at every checkpoint by including the lines

# %%
# Saving model parameters and weights per epoch
#checkpoint_filepath = 'F:\\MRI_class\\data\\Alzheimer_s Dataset_20percentVal\\SimpleCNN_lr10-4\\checkpoint_model.epoch{epoch:02d}-recall{val_recall:.2f}.hdf5'
#model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_filepath, save_weights_only=False, monitor='val_recall', mode='max',
#save_best_only=True)

# Model training. Model weights are saved at the end of every epoch, if it's the best seen so far
with tf.device("/gpu:0"):
    tf.random.set_seed(10)
    model_history = model.fit(x=train_fullTensor,
                        validation_data=val_fullTensor,
                        epochs=50, 
                        shuffle=True
                        #callbacks=[model_checkpoint_callback]
                        )
# Out:
# Epoch 1/50
# 144/144 [==============================] - 28s 132ms/step - loss: 1.0132 - precision: 0.5543 - recall: 0.2906 - val_loss: 1.1772 - val_precision: 0.3684 - val_recall: 0.1690
# Epoch 2/50
# 144/144 [==============================] - 16s 111ms/step - loss: 0.8081 - precision: 0.6926 - recall: 0.5134 - val_loss: 1.1468 - val_precision: 0.4542 - val_recall: 0.2760
# Epoch 3/50
# 144/144 [==============================] - 16s 111ms/step - loss: 0.6698 - precision: 0.7474 - recall: 0.6291 - val_loss: 1.2136 - val_precision: 0.4815 - val_recall: 0.3529
# Epoch 4/50
# 144/144 [==============================] - 16s 111ms/step - loss: 0.5341 - precision: 0.8084 - recall: 0.7331 - val_loss: 1.3034 - val_precision: 0.4462 - val_recall: 0.3494
# Epoch 5/50
# 144/144 [==============================] - 16s 111ms/step - loss: 0.4308 - precision: 0.8492 - recall: 0.8024 - val_loss: 1.3136 - val_precision: 0.5091 - val_recall: 0.4411
# Epoch 6/50
# 144/144 [==============================] - 16s 111ms/step - loss: 0.3534 - precision: 0.8760 - recall: 0.8421 - val_loss: 1.3139 - val_precision: 0.5193 - val_recall: 0.4648
# Epoch 7/50
# 144/144 [==============================] - 16s 111ms/step - loss: 0.2744 - precision: 0.9024 - recall: 0.8832 - val_loss: 1.2879 - val_precision: 0.5396 - val_recall: 0.4998
# Epoch 8/50
# 144/144 [==============================] - 16s 112ms/step - loss: 0.2237 - precision: 0.9231 - recall: 0.9075 - val_loss: 1.2478 - val_precision: 0.5853 - val_recall: 0.5510
# Epoch 9/50
# 144/144 [==============================] - 16s 112ms/step - loss: 0.1851 - precision: 0.9359 - recall: 0.9262 - val_loss: 1.5842 - val_precision: 0.4974 - val_recall: 0.4648
# Epoch 10/50
# 144/144 [==============================] - 16s 110ms/step - loss: 0.1325 - precision: 0.9572 - recall: 0.9509 - val_loss: 1.6486 - val_precision: 0.4877 - val_recall: 0.4608
# Epoch 11/50
# 144/144 [==============================] - 16s 110ms/step - loss: 0.1152 - precision: 0.9634 - recall: 0.9605 - val_loss: 2.1680 - val_precision: 0.4903 - val_recall: 0.4751
# Epoch 12/50
# 144/144 [==============================] - 16s 111ms/step - loss: 0.1019 - precision: 0.9659 - recall: 0.9607 - val_loss: 2.1666 - val_precision: 0.5275 - val_recall: 0.5106
# Epoch 13/50
# 144/144 [==============================] - 16s 112ms/step - loss: 0.0777 - precision: 0.9747 - recall: 0.9711 - val_loss: 2.4794 - val_precision: 0.4499 - val_recall: 0.4293
# Epoch 14/50
# 144/144 [==============================] - 16s 112ms/step - loss: 0.0687 - precision: 0.9795 - recall: 0.9752 - val_loss: 2.2322 - val_precision: 0.4815 - val_recall: 0.4692
# Epoch 15/50
# 144/144 [==============================] - 16s 110ms/step - loss: 0.0575 - precision: 0.9826 - recall: 0.9813 - val_loss: 2.0463 - val_precision: 0.4922 - val_recall: 0.4692
# Epoch 16/50
# 144/144 [==============================] - 16s 113ms/step - loss: 0.0441 - precision: 0.9863 - recall: 0.9848 - val_loss: 1.8463 - val_precision: 0.5477 - val_recall: 0.5239
# Epoch 17/50
# 144/144 [==============================] - 16s 111ms/step - loss: 0.0441 - precision: 0.9848 - recall: 0.9831 - val_loss: 2.1401 - val_precision: 0.5223 - val_recall: 0.5081
# Epoch 18/50
# 144/144 [==============================] - 16s 111ms/step - loss: 0.0386 - precision: 0.9887 - recall: 0.9872 - val_loss: 2.3917 - val_precision: 0.5162 - val_recall: 0.5017
# Epoch 19/50
# 144/144 [==============================] - 16s 111ms/step - loss: 0.0332 - precision: 0.9896 - recall: 0.9878 - val_loss: 1.9568 - val_precision: 0.5400 - val_recall: 0.5254
# Epoch 20/50
# 144/144 [==============================] - 16s 111ms/step - loss: 0.0320 - precision: 0.9915 - recall: 0.9909 - val_loss: 2.3063 - val_precision: 0.4975 - val_recall: 0.4815
# Epoch 21/50
# 144/144 [==============================] - 16s 111ms/step - loss: 0.0337 - precision: 0.9889 - recall: 0.9883 - val_loss: 2.4443 - val_precision: 0.4871 - val_recall: 0.4756
# Epoch 22/50
# 144/144 [==============================] - 16s 110ms/step - loss: 0.0214 - precision: 0.9941 - recall: 0.9933 - val_loss: 1.9358 - val_precision: 0.5894 - val_recall: 0.5786
# Epoch 23/50
# 144/144 [==============================] - 16s 111ms/step - loss: 0.0224 - precision: 0.9933 - recall: 0.9926 - val_loss: 1.9661 - val_precision: 0.5140 - val_recall: 0.4978
# Epoch 24/50
# 144/144 [==============================] - 16s 110ms/step - loss: 0.0223 - precision: 0.9935 - recall: 0.9928 - val_loss: 1.8584 - val_precision: 0.5628 - val_recall: 0.5451
# Epoch 25/50
# 144/144 [==============================] - 16s 110ms/step - loss: 0.0234 - precision: 0.9913 - recall: 0.9909 - val_loss: 1.9086 - val_precision: 0.5727 - val_recall: 0.5628
# Epoch 26/50
# 144/144 [==============================] - 16s 110ms/step - loss: 0.0227 - precision: 0.9920 - recall: 0.9917 - val_loss: 2.0771 - val_precision: 0.5418 - val_recall: 0.5298
# Epoch 27/50
# 144/144 [==============================] - 16s 111ms/step - loss: 0.0202 - precision: 0.9933 - recall: 0.9924 - val_loss: 1.8275 - val_precision: 0.6204 - val_recall: 0.6082
# Epoch 28/50
# 144/144 [==============================] - 16s 111ms/step - loss: 0.0169 - precision: 0.9948 - recall: 0.9946 - val_loss: 1.8272 - val_precision: 0.5966 - val_recall: 0.5845
# Epoch 29/50
# 144/144 [==============================] - 16s 110ms/step - loss: 0.0176 - precision: 0.9935 - recall: 0.9933 - val_loss: 1.9983 - val_precision: 0.5660 - val_recall: 0.5559
# Epoch 30/50
# 144/144 [==============================] - 16s 110ms/step - loss: 0.0179 - precision: 0.9937 - recall: 0.9935 - val_loss: 1.6758 - val_precision: 0.6324 - val_recall: 0.6225
# Epoch 31/50
# 144/144 [==============================] - 16s 110ms/step - loss: 0.0176 - precision: 0.9930 - recall: 0.9928 - val_loss: 1.8037 - val_precision: 0.5860 - val_recall: 0.5742
# Epoch 32/50
# 144/144 [==============================] - 16s 111ms/step - loss: 0.0181 - precision: 0.9946 - recall: 0.9944 - val_loss: 2.2803 - val_precision: 0.5088 - val_recall: 0.4978
# Epoch 33/50
# 144/144 [==============================] - 16s 110ms/step - loss: 0.0122 - precision: 0.9965 - recall: 0.9963 - val_loss: 2.0756 - val_precision: 0.5338 - val_recall: 0.5209
# Epoch 34/50
# 144/144 [==============================] - 16s 111ms/step - loss: 0.0138 - precision: 0.9957 - recall: 0.9954 - val_loss: 2.1201 - val_precision: 0.5872 - val_recall: 0.5806
# Epoch 35/50
# 144/144 [==============================] - 16s 111ms/step - loss: 0.0135 - precision: 0.9946 - recall: 0.9946 - val_loss: 2.1104 - val_precision: 0.5827 - val_recall: 0.5747
# Epoch 36/50
# 144/144 [==============================] - 16s 109ms/step - loss: 0.0109 - precision: 0.9963 - recall: 0.9963 - val_loss: 2.0126 - val_precision: 0.5839 - val_recall: 0.5781
# Epoch 37/50
# 144/144 [==============================] - 15s 107ms/step - loss: 0.0108 - precision: 0.9961 - recall: 0.9961 - val_loss: 2.4681 - val_precision: 0.5504 - val_recall: 0.5407
# Epoch 38/50
# 144/144 [==============================] - 15s 108ms/step - loss: 0.0093 - precision: 0.9976 - recall: 0.9972 - val_loss: 2.2835 - val_precision: 0.5625 - val_recall: 0.5545
# Epoch 39/50
# 144/144 [==============================] - 16s 108ms/step - loss: 0.0093 - precision: 0.9970 - recall: 0.9970 - val_loss: 2.3417 - val_precision: 0.5441 - val_recall: 0.5382
# Epoch 40/50
# 144/144 [==============================] - 15s 107ms/step - loss: 0.0069 - precision: 0.9970 - recall: 0.9970 - val_loss: 2.3491 - val_precision: 0.5812 - val_recall: 0.5752
# Epoch 41/50
# 144/144 [==============================] - 16s 108ms/step - loss: 0.0165 - precision: 0.9954 - recall: 0.9952 - val_loss: 2.5587 - val_precision: 0.5353 - val_recall: 0.5274
# Epoch 42/50
# 144/144 [==============================] - 15s 108ms/step - loss: 0.0099 - precision: 0.9965 - recall: 0.9965 - val_loss: 2.1512 - val_precision: 0.5553 - val_recall: 0.5490
# Epoch 43/50
# 144/144 [==============================] - 15s 107ms/step - loss: 0.0148 - precision: 0.9954 - recall: 0.9954 - val_loss: 2.4018 - val_precision: 0.5265 - val_recall: 0.5190
# Epoch 44/50
# 144/144 [==============================] - 15s 108ms/step - loss: 0.0098 - precision: 0.9967 - recall: 0.9967 - val_loss: 1.9953 - val_precision: 0.5993 - val_recall: 0.5934
# Epoch 45/50
# 144/144 [==============================] - 16s 111ms/step - loss: 0.0045 - precision: 0.9987 - recall: 0.9987 - val_loss: 2.0083 - val_precision: 0.5838 - val_recall: 0.5737
# Epoch 46/50
# 144/144 [==============================] - 16s 111ms/step - loss: 0.0064 - precision: 0.9983 - recall: 0.9980 - val_loss: 2.2912 - val_precision: 0.5694 - val_recall: 0.5643
# Epoch 47/50
# 144/144 [==============================] - 16s 109ms/step - loss: 0.0074 - precision: 0.9978 - recall: 0.9976 - val_loss: 2.4024 - val_precision: 0.5403 - val_recall: 0.5352
# Epoch 48/50
# 144/144 [==============================] - 16s 112ms/step - loss: 0.0092 - precision: 0.9976 - recall: 0.9974 - val_loss: 2.0724 - val_precision: 0.6039 - val_recall: 0.5988
# Epoch 49/50
# 144/144 [==============================] - 16s 110ms/step - loss: 0.0064 - precision: 0.9978 - recall: 0.9976 - val_loss: 2.2794 - val_precision: 0.5661 - val_recall: 0.5594
# Epoch 50/50
# 144/144 [==============================] - 16s 110ms/step - loss: 0.0038 - precision: 0.9989 - recall: 0.9989 - val_loss: 2.1127 - val_precision: 0.5729 - val_recall: 0.5633

# %% [markdown]
# ### Visualize Training Results

# %%
plt.plot(model_history.history['recall'], label='recall')
plt.plot(model_history.history['val_recall'], label = 'val_recall')
plt.xlabel('Epoch')
plt.ylabel('recall')
plt.ylim([0, 1])
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ### Save the Model

# %%
#model.save('F:\\MRI_class\\data\\Alzheimer_s Dataset_30percentVal\\InceptionV3_LR10-5_augm_Oversample\\')
#model.save('F:\\MRI_class\\data\\Alzheimer_s Dataset_30percentVal\\InceptionV3_LR10-5_augm_Oversample\\h5\\model_1.h5')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 94). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: F:\MRI_class\data\Alzheimer_s Dataset_30percentVal\InceptionV3_LR10-5_augm_Oversample\assets
# INFO:tensorflow:Assets written to: F:\MRI_class\data\Alzheimer_s Dataset_30percentVal\InceptionV3_LR10-5_augm_Oversample\assets

# %% [markdown]
# ### Load a Testset

# %%
oasis_img_temp, oasis_label_temp = load_oasis_set_win()
# Out:
# Image Array Shape: (231, 208, 176, 3)
#
# Image Count: 231
#
# labels: [0. 1. 2. 3.]
#
# Class Counts:
#       ID
# CDR
# 0.0  131
# 1.0   70
# 2.0   28
# 3.0    2

# %% [markdown]
# ### Get only classes 0, 1 and 2 of the Testset

# %%
oasis_images = []
oasis_labels = []
for image,label in zip(oasis_img_temp,oasis_label_temp):
    if int(label) == 3:
        continue
    if int(label) == 0:
        #image = image/255
        oasis_images.append(cv2.flip(image,0))
        oasis_labels.append([1,0,0])
    if int(label) == 1:
        #image = image/255
        oasis_images.append(cv2.flip(image,0))
        oasis_labels.append([0,1,0])
    if int(label) == 2:
        #image = image/255
        oasis_images.append(cv2.flip(image,0))
        oasis_labels.append([0,0,1])

oasis_images = np.array(oasis_images)
oasis_labels = np.array(oasis_labels)

# %%
plt.imshow(oasis_images[0].astype("uint8"))

# %% [markdown]
# ### Perform a Prediction on the Testset and Visualize the Results

# %%
oasis_pred = model.predict(oasis_images, batch_size=1)
# Out:
# 229/229 [==============================] - 3s 15ms/step

# %%
precision_recall_multiclass(oasis_pred,oasis_labels,["healthy","veryMildAD","mildAD"])
# Out:
# -----Recalls-----
# healthy Recall: 0.4961832061068702
# veryMildAD Recall: 0.6571428571428571
# mildAD Recall: 0.39285714285714285
# -------#####-------
#
#
# -----Precisions-----
# healthy Precision: 0.8333333333333334
# veryMildAD Precision: 0.4791666666666667
# mildAD Precision: 0.2
# -------#####-------
#
#
# -----Accuracy-----
# healthy Accuracy: 0.8333333333333334
# veryMildAD Accuracy: 0.4791666666666667
# mildAD Accuracy: 0.2
# -------#####-------
#
#
# -----Macro Recall and Precisions-----
# Macro recall: 0.5153944020356234
# Macro recall: 0.5041666666666667
# ------------#####------------
