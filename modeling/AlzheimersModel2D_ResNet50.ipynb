# %%
#load all packages

# base packages
import keras
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2

# tensorflow and keras
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.utils import image_dataset_from_directory
from keras import metrics

# sklearn
from sklearn.utils import shuffle
from sklearn.metrics import recall_score, precision_score, confusion_matrix

# self-build procedures
from roc_multiclass import roc_multiclass
from precision_recall_multiclass import precision_recall_multiclass
from load_oasis_set import load_oasis_set
from load_oasis_set_win import load_oasis_set_win
from DataGenerator import DataGenerator

# model architectures
from cnn_backbone import base_model

# %% [markdown]
# ### Load Train Data and oversample

# %%
# load dataset from drive
#PATH = "/Users/josealbertodiazsalas/Documents/Alzheimer_s Dataset/train"
PATH = "F:\\MRI_class\\data\\Alzheimer_s Dataset_30percentVal\\train"
IMAGE_SIZE = (208, 176)
train_ds = image_dataset_from_directory(
                                        PATH, 
                                        seed=10, 
                                        shuffle=False,              #<---
                                        image_size=IMAGE_SIZE, 
                                        batch_size=32
                                        )
                                        
# one hot encode the labels to fit into the cnn layers
train_ds = train_ds.map(lambda x, y: (x, tf.one_hot(y, depth=3)))
# Out:
# Found 3040 files belonging to 3 classes.

# %% [markdown]
# ### Deconstuct Train Dataset and Prepare for Oversampling

# %%
# seperation of validation set
# !!! these sets are not shuffled !!!

train_big = train_ds
X1_train_big = []
y1_train_big = []
X2_train_big = []
y2_train_big = []
X3_train_big = []
y3_train_big = []


for img, label in train_ds.unbatch():
    if label.numpy()[0] == 1:
        X1_train_big.append(img.numpy())
        y1_train_big.append(label.numpy())

    if label.numpy()[1] == 1:
        X2_train_big.append(img.numpy())
        y2_train_big.append(label.numpy())

    if label.numpy()[2] == 1:
        X3_train_big.append(img.numpy())
        y3_train_big.append(label.numpy())

# %% [markdown]
# ### Oversampling
# Fill classes to match class 0 (Healthy)

# %%
# create dataset for class 1 -NO oversampling- (healthy)
X1_train_big = np.array(X1_train_big)
y1_train_big = np.array(y1_train_big)

# %%
# oversampling for class 2 (very mild)

randomPicksIdx = [np.random.choice(len(X2_train_big)) for i in range(len(X1_train_big) - len(X2_train_big))]

for i in randomPicksIdx:
    X2_train_big.append(X2_train_big[i])
    y2_train_big.append(y2_train_big[i])

X2_train_big = np.array(X2_train_big)
y2_train_big = np.array(y2_train_big)

# %%
# oversampling for class 3 (mild)
randomPicksIdx = [np.random.choice(len(X3_train_big)) for i in range(len(X1_train_big) - len(X3_train_big))]            # images are randomly picked

for i in randomPicksIdx:
    X3_train_big.append(X3_train_big[i])
    y3_train_big.append(y3_train_big[i])

X3_train_big = np.array(X3_train_big)
y3_train_big = np.array(y3_train_big)

# %% [markdown]
# ### Construct full Dataset Tensor for Training

# %%
# combine all data sets
X_train_fullset = np.concatenate((X1_train_big,X2_train_big,X3_train_big), axis=0)
y_train_fullset = np.concatenate((y1_train_big,y2_train_big,y3_train_big), axis=0)

# %%
# shuffle the whole set
X_train_temp, y_train_temp = shuffle(X_train_fullset, y_train_fullset, random_state=10)

# %%
# finally create tensor dataset
data_generator = DataGenerator(X_train_temp, y_train_temp, batch_size = 32)

train_fullTensor = tf.data.Dataset.from_generator(
                                            data_generator,
                                            output_signature=(tf.TensorSpec(shape=(None, 208, 176, 3), dtype=tf.float32), tf.TensorSpec(shape=(None, 3), dtype=tf.float32))
                                            )

# %% [markdown]
# ### Load Validation Set

# %%
# load validation dataset from drive
# set for training
#PATH = "/Users/josealbertodiazsalas/Documents/Alzheimer_s Dataset/train"
PATH = "F:\\MRI_class\\data\\Alzheimer_s Dataset_30percentVal\\validation"
IMAGE_SIZE = (208, 176)
val_ds = image_dataset_from_directory(
                                        PATH, 
                                        seed=10, 
                                        shuffle=True, 
                                        image_size=IMAGE_SIZE, 
                                        batch_size=32
                                        )

# one hot encode the labels to fit into the cnn layers
val_fullTensor = val_ds.map(lambda x, y: (x, tf.one_hot(y, depth=3)))
# Out:
# Found 2029 files belonging to 3 classes.

# %% [markdown]
# ### Check Images for Integrity

# %%
# plot some example images from loaded set
plt.figure(figsize=(10, 10))
for images, labels in train_fullTensor.take(1):
  for i in range(3):
    ax = plt.subplot(1, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"), cmap="gray")
    plt.title([labels[i].numpy()][0])
    plt.axis("off")
# Out:
# f:\env\lib\site-packages\matplotlib\text.py:1223: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %% [markdown]
# # Creating CNN Architecture
# ### First Creating Augmentation Module

# %%
with tf.device("/gpu:0"):
    data_augmentation = keras.Sequential([
        layers.InputLayer(input_shape=(208, 176, 3)),
        layers.Lambda(lambda x: tf.image.resize(x, (208, 176))),
        layers.Lambda(lambda x: tf.image.random_contrast(x,0.6,1)),
        layers.Lambda(lambda x: tf.image.random_brightness(x,0.3)),             #<--- delta value depends on image range. if 0-1 delta should be between 0-1. if 0-255 delta should be between 0-255
        layers.RandomRotation(0.01),
        layers.RandomFlip(mode="horizontal"),    
        layers.RandomZoom(0.03),
        #layers.RandomBrightness((0.2), value_range=(0,255)),
        #layers.Resizing(208, 176),
        #layers.RandomContrast((0.2))
])

# %% [markdown]
# ### Check Images for proper Augmentation

# %%
with tf.device("/gpu:0"):
    plt.figure(figsize=(10, 10))
    for images, labels in train_fullTensor.take(1):
        for i in range(3):
            ax = plt.subplot(1, 3, i + 1)
            img = data_augmentation(images/255)             # divided by 255 (normalization) since augmentation depends on normalization which is 
            plt.imshow(img[i].numpy(), cmap="gray")         # a specific layer in the CNN and not part of augmentation
            plt.title([labels[i].numpy()][0])
            plt.axis("off")
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ### Building the complete CNN
# #### Construct ResNet50 Backbone

# %%
# Defining both base and final model architecture
b_model = base_model(MODEL='ResNet50', freeze_layers=False)
b_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 32s 0us/step
# Model: "resnet50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 208, 176, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 214, 182, 3)  0           ['input_2[0][0]']
#
#  conv1_conv (Conv2D)            (None, 104, 88, 64)  9472        ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalization)  (None, 104, 88, 64)  256         ['conv1_conv[0][0]']
#
#  conv1_relu (Activation)        (None, 104, 88, 64)  0           ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)      (None, 106, 90, 64)  0           ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)      (None, 52, 44, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 52, 44, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 52, 44, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 52, 44, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 52, 44, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 52, 44, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 52, 44, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 52, 44, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 52, 44, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 52, 44, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 52, 44, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 52, 44, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 52, 44, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 52, 44, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 52, 44, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 52, 44, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 52, 44, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 52, 44, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 52, 44, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 52, 44, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 52, 44, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 52, 44, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 52, 44, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 52, 44, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 52, 44, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 52, 44, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 52, 44, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 52, 44, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 52, 44, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 52, 44, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 52, 44, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 52, 44, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 52, 44, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 26, 22, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 26, 22, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 26, 22, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 26, 22, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 26, 22, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 26, 22, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 26, 22, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 26, 22, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 26, 22, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 26, 22, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 26, 22, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 26, 22, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 26, 22, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 26, 22, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 26, 22, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 26, 22, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 26, 22, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 26, 22, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 26, 22, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 26, 22, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 26, 22, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 26, 22, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 26, 22, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 26, 22, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 26, 22, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 26, 22, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 26, 22, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 26, 22, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 26, 22, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 26, 22, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 26, 22, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 26, 22, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 26, 22, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 26, 22, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 26, 22, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 26, 22, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 26, 22, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 26, 22, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 26, 22, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 26, 22, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 26, 22, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 26, 22, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 13, 11, 256)  131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 13, 11, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 13, 11, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 13, 11, 256)  590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 13, 11, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 13, 11, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 13, 11, 1024  525312      ['conv3_block4_out[0][0]']
#                                 )
#
#  conv4_block1_3_conv (Conv2D)   (None, 13, 11, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_0_bn (BatchNormal  (None, 13, 11, 1024  4096       ['conv4_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_3_bn (BatchNormal  (None, 13, 11, 1024  4096       ['conv4_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_add (Add)         (None, 13, 11, 1024  0           ['conv4_block1_0_bn[0][0]',
#                                 )                                 'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 13, 11, 1024  0           ['conv4_block1_add[0][0]']
#                                 )
#
#  conv4_block2_1_conv (Conv2D)   (None, 13, 11, 256)  262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 13, 11, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 13, 11, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 13, 11, 256)  590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 13, 11, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 13, 11, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 13, 11, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_3_bn (BatchNormal  (None, 13, 11, 1024  4096       ['conv4_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block2_add (Add)         (None, 13, 11, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 13, 11, 1024  0           ['conv4_block2_add[0][0]']
#                                 )
#
#  conv4_block3_1_conv (Conv2D)   (None, 13, 11, 256)  262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 13, 11, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 13, 11, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 13, 11, 256)  590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 13, 11, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 13, 11, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 13, 11, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_3_bn (BatchNormal  (None, 13, 11, 1024  4096       ['conv4_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block3_add (Add)         (None, 13, 11, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 13, 11, 1024  0           ['conv4_block3_add[0][0]']
#                                 )
#
#  conv4_block4_1_conv (Conv2D)   (None, 13, 11, 256)  262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 13, 11, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 13, 11, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 13, 11, 256)  590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 13, 11, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 13, 11, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 13, 11, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_3_bn (BatchNormal  (None, 13, 11, 1024  4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block4_add (Add)         (None, 13, 11, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 13, 11, 1024  0           ['conv4_block4_add[0][0]']
#                                 )
#
#  conv4_block5_1_conv (Conv2D)   (None, 13, 11, 256)  262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 13, 11, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 13, 11, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 13, 11, 256)  590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 13, 11, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 13, 11, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 13, 11, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_3_bn (BatchNormal  (None, 13, 11, 1024  4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block5_add (Add)         (None, 13, 11, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 13, 11, 1024  0           ['conv4_block5_add[0][0]']
#                                 )
#
#  conv4_block6_1_conv (Conv2D)   (None, 13, 11, 256)  262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 13, 11, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 13, 11, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 13, 11, 256)  590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 13, 11, 256)  1024       ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 13, 11, 256)  0          ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 13, 11, 1024  263168      ['conv4_block6_2_relu[0][0]']
#                                 )
#
#  conv4_block6_3_bn (BatchNormal  (None, 13, 11, 1024  4096       ['conv4_block6_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block6_add (Add)         (None, 13, 11, 1024  0           ['conv4_block5_out[0][0]',
#                                 )                                 'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 13, 11, 1024  0           ['conv4_block6_add[0][0]']
#                                 )
#
#  conv5_block1_1_conv (Conv2D)   (None, 7, 6, 512)    524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 7, 6, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 7, 6, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 7, 6, 512)    2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 7, 6, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 7, 6, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 7, 6, 2048)   2099200     ['conv4_block6_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 7, 6, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 7, 6, 2048)  8192        ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 7, 6, 2048)  8192        ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 7, 6, 2048)   0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 7, 6, 2048)   0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 7, 6, 512)    1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 7, 6, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 7, 6, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 7, 6, 512)    2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 7, 6, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 7, 6, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 7, 6, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_3_bn (BatchNormal  (None, 7, 6, 2048)  8192        ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 7, 6, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 7, 6, 2048)   0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 7, 6, 512)    1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 7, 6, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 7, 6, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 7, 6, 512)    2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 7, 6, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 7, 6, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 7, 6, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 7, 6, 2048)  8192        ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 7, 6, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 7, 6, 2048)   0           ['conv5_block3_add[0][0]']
#
# ==================================================================================================
# Total params: 23,587,712
# Trainable params: 23,534,592
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %% [markdown]
# ### Combine Backbone with Augmentation and Dense Layers

# %%
# Definition conv and classification layers
model = models.Sequential()
model.add(layers.InputLayer(input_shape=(208, 176, 3)))
model.add(layers.Rescaling(1.0/255))
model.add(data_augmentation)
model.add(b_model)
model.add(layers.Flatten())
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dropout(0.3))
model.add(layers.Dense(3, activation="softmax"))

# Print only Conv and Pooling layer from model architecture
model.build()
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 208, 176, 3)       0
#
#  sequential (Sequential)     (None, 208, 176, 3)       0
#
#  resnet50 (Functional)       (None, 7, 6, 2048)        23587712
#
#  flatten (Flatten)           (None, 86016)             0
#
#  dense (Dense)               (None, 512)               44040704
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_2 (Dense)             (None, 3)                 1539
#
# =================================================================
# Total params: 67,892,611
# Trainable params: 67,839,491
# Non-trainable params: 53,120
# _________________________________________________________________

# %% [markdown]
# ### Defining the Optimizer

# %%
# Defining optimizer and learning rate
lr_schedule = tf.keras.optimizers.schedules.InverseTimeDecay(
    0.00001,
    decay_steps=10000,
    decay_rate=1,
    staircase=False)
optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule, name='Adam')

# %% [markdown]
# ### Compile the CNN Architecture

# %%
# Freeze the the behavior of that model. If any trainable value changes, compile() must be called again
keras.backend.clear_session()
model.compile(optimizer=optimizer,
    loss="CategoricalCrossentropy",
    metrics=[metrics.Precision(), metrics.Recall()])

# %% [markdown]
# ### Train the Model
# You can chose the save the model iterativly at every checkpoint by including the lines

# %%
# Saving model parameters and weights per epoch
#checkpoint_filepath = 'F:\\MRI_class\\data\\Alzheimer_s Dataset_20percentVal\\SimpleCNN_lr10-4\\checkpoint_model.epoch{epoch:02d}-recall{val_recall:.2f}.hdf5'
#model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_filepath, save_weights_only=False, monitor='val_recall', mode='max',
#save_best_only=True)

# Model training. Model weights are saved at the end of every epoch, if it's the best seen so far
with tf.device("/gpu:0"):
    tf.random.set_seed(10)
    model_history = model.fit(x=train_fullTensor,
                        validation_data=val_fullTensor,
                        epochs=50, 
                        shuffle=True
                        #callbacks=[model_checkpoint_callback]
                        )
# Out:
# Epoch 1/50
# 144/144 [==============================] - 29s 152ms/step - loss: 1.0135 - precision: 0.5786 - recall: 0.4749 - val_loss: 17.7594 - val_precision: 0.1414 - val_recall: 0.1414
# Epoch 2/50
# 144/144 [==============================] - 20s 140ms/step - loss: 0.7087 - precision: 0.7214 - recall: 0.6213 - val_loss: 26.8246 - val_precision: 0.1414 - val_recall: 0.1414
# Epoch 3/50
# 144/144 [==============================] - 20s 140ms/step - loss: 0.5703 - precision: 0.7916 - recall: 0.7257 - val_loss: 21.2480 - val_precision: 0.1414 - val_recall: 0.1414
# Epoch 4/50
# 144/144 [==============================] - 20s 141ms/step - loss: 0.4502 - precision: 0.8384 - recall: 0.7887 - val_loss: 17.0304 - val_precision: 0.1414 - val_recall: 0.1414
# Epoch 5/50
# 144/144 [==============================] - 20s 142ms/step - loss: 0.3495 - precision: 0.8767 - recall: 0.8443 - val_loss: 13.4870 - val_precision: 0.1414 - val_recall: 0.1414
# Epoch 6/50
# 144/144 [==============================] - 20s 141ms/step - loss: 0.2877 - precision: 0.8956 - recall: 0.8740 - val_loss: 5.8356 - val_precision: 0.1913 - val_recall: 0.1897
# Epoch 7/50
# 144/144 [==============================] - 20s 141ms/step - loss: 0.2183 - precision: 0.9211 - recall: 0.9055 - val_loss: 2.1804 - val_precision: 0.4206 - val_recall: 0.3992
# Epoch 8/50
# 144/144 [==============================] - 20s 140ms/step - loss: 0.1719 - precision: 0.9395 - recall: 0.9312 - val_loss: 1.3602 - val_precision: 0.5521 - val_recall: 0.5328
# Epoch 9/50
# 144/144 [==============================] - 20s 139ms/step - loss: 0.1366 - precision: 0.9536 - recall: 0.9453 - val_loss: 1.4585 - val_precision: 0.5217 - val_recall: 0.4924
# Epoch 10/50
# 144/144 [==============================] - 20s 140ms/step - loss: 0.1065 - precision: 0.9651 - recall: 0.9607 - val_loss: 1.4872 - val_precision: 0.5331 - val_recall: 0.5160
# Epoch 11/50
# 144/144 [==============================] - 20s 140ms/step - loss: 0.0827 - precision: 0.9705 - recall: 0.9661 - val_loss: 1.5383 - val_precision: 0.5707 - val_recall: 0.5510
# Epoch 12/50
# 144/144 [==============================] - 20s 140ms/step - loss: 0.0773 - precision: 0.9732 - recall: 0.9692 - val_loss: 1.3926 - val_precision: 0.6315 - val_recall: 0.6141
# Epoch 13/50
# 144/144 [==============================] - 20s 141ms/step - loss: 0.0730 - precision: 0.9752 - recall: 0.9729 - val_loss: 1.7686 - val_precision: 0.6162 - val_recall: 0.5998
# Epoch 14/50
# 144/144 [==============================] - 20s 141ms/step - loss: 0.0552 - precision: 0.9809 - recall: 0.9792 - val_loss: 1.3157 - val_precision: 0.6667 - val_recall: 0.6545
# Epoch 15/50
# 144/144 [==============================] - 20s 142ms/step - loss: 0.0503 - precision: 0.9822 - recall: 0.9809 - val_loss: 1.3307 - val_precision: 0.6805 - val_recall: 0.6708
# Epoch 16/50
# 144/144 [==============================] - 20s 140ms/step - loss: 0.0378 - precision: 0.9881 - recall: 0.9878 - val_loss: 1.3298 - val_precision: 0.7014 - val_recall: 0.6900
# Epoch 17/50
# 144/144 [==============================] - 20s 140ms/step - loss: 0.0339 - precision: 0.9889 - recall: 0.9883 - val_loss: 1.2860 - val_precision: 0.7081 - val_recall: 0.6959
# Epoch 18/50
# 144/144 [==============================] - 20s 140ms/step - loss: 0.0266 - precision: 0.9920 - recall: 0.9915 - val_loss: 1.3585 - val_precision: 0.6938 - val_recall: 0.6856
# Epoch 19/50
# 144/144 [==============================] - 20s 141ms/step - loss: 0.0236 - precision: 0.9920 - recall: 0.9915 - val_loss: 1.2864 - val_precision: 0.7252 - val_recall: 0.7166
# Epoch 20/50
# 144/144 [==============================] - 20s 141ms/step - loss: 0.0267 - precision: 0.9915 - recall: 0.9911 - val_loss: 1.2348 - val_precision: 0.7277 - val_recall: 0.7206
# Epoch 21/50
# 144/144 [==============================] - 20s 140ms/step - loss: 0.0203 - precision: 0.9946 - recall: 0.9939 - val_loss: 1.4923 - val_precision: 0.7019 - val_recall: 0.6974
# Epoch 22/50
# 144/144 [==============================] - 20s 140ms/step - loss: 0.0195 - precision: 0.9952 - recall: 0.9944 - val_loss: 1.2723 - val_precision: 0.7347 - val_recall: 0.7260
# Epoch 23/50
# 144/144 [==============================] - 20s 140ms/step - loss: 0.0158 - precision: 0.9961 - recall: 0.9961 - val_loss: 1.4544 - val_precision: 0.7054 - val_recall: 0.6999
# Epoch 24/50
# 144/144 [==============================] - 20s 139ms/step - loss: 0.0183 - precision: 0.9954 - recall: 0.9954 - val_loss: 1.3248 - val_precision: 0.7015 - val_recall: 0.6949
# Epoch 25/50
# 144/144 [==============================] - 20s 140ms/step - loss: 0.0123 - precision: 0.9961 - recall: 0.9961 - val_loss: 1.3845 - val_precision: 0.7173 - val_recall: 0.7141
# Epoch 26/50
# 144/144 [==============================] - 20s 141ms/step - loss: 0.0147 - precision: 0.9950 - recall: 0.9950 - val_loss: 1.3826 - val_precision: 0.7234 - val_recall: 0.7181
# Epoch 27/50
# 144/144 [==============================] - 20s 140ms/step - loss: 0.0120 - precision: 0.9959 - recall: 0.9957 - val_loss: 1.2401 - val_precision: 0.7674 - val_recall: 0.7624
# Epoch 28/50
# 144/144 [==============================] - 20s 140ms/step - loss: 0.0126 - precision: 0.9959 - recall: 0.9959 - val_loss: 1.2770 - val_precision: 0.7420 - val_recall: 0.7383
# Epoch 29/50
# 144/144 [==============================] - 20s 140ms/step - loss: 0.0107 - precision: 0.9970 - recall: 0.9970 - val_loss: 1.5162 - val_precision: 0.7069 - val_recall: 0.7013
# Epoch 30/50
# 144/144 [==============================] - 20s 139ms/step - loss: 0.0103 - precision: 0.9974 - recall: 0.9972 - val_loss: 1.0983 - val_precision: 0.7830 - val_recall: 0.7787
# Epoch 31/50
# 144/144 [==============================] - 20s 140ms/step - loss: 0.0103 - precision: 0.9970 - recall: 0.9967 - val_loss: 1.7003 - val_precision: 0.7095 - val_recall: 0.7068
# Epoch 32/50
# 144/144 [==============================] - 20s 140ms/step - loss: 0.0087 - precision: 0.9978 - recall: 0.9978 - val_loss: 1.6301 - val_precision: 0.6958 - val_recall: 0.6934
# Epoch 33/50
# 144/144 [==============================] - 19s 135ms/step - loss: 0.0098 - precision: 0.9965 - recall: 0.9961 - val_loss: 1.7223 - val_precision: 0.6751 - val_recall: 0.6698
# Epoch 34/50
# 144/144 [==============================] - 20s 136ms/step - loss: 0.0105 - precision: 0.9967 - recall: 0.9965 - val_loss: 1.7815 - val_precision: 0.7005 - val_recall: 0.6964
# Epoch 35/50
# 144/144 [==============================] - 20s 136ms/step - loss: 0.0127 - precision: 0.9954 - recall: 0.9950 - val_loss: 1.5548 - val_precision: 0.7302 - val_recall: 0.7270
# Epoch 36/50
# 144/144 [==============================] - 20s 136ms/step - loss: 0.0115 - precision: 0.9970 - recall: 0.9967 - val_loss: 1.3175 - val_precision: 0.7624 - val_recall: 0.7590
# Epoch 37/50
# 144/144 [==============================] - 19s 135ms/step - loss: 0.0138 - precision: 0.9952 - recall: 0.9952 - val_loss: 1.2938 - val_precision: 0.7519 - val_recall: 0.7496
# Epoch 38/50
# 144/144 [==============================] - 20s 138ms/step - loss: 0.0074 - precision: 0.9974 - recall: 0.9974 - val_loss: 1.2601 - val_precision: 0.7542 - val_recall: 0.7516
# Epoch 39/50
# 144/144 [==============================] - 20s 140ms/step - loss: 0.0102 - precision: 0.9970 - recall: 0.9970 - val_loss: 2.0306 - val_precision: 0.7034 - val_recall: 0.7013
# Epoch 40/50
# 144/144 [==============================] - 20s 140ms/step - loss: 0.0164 - precision: 0.9937 - recall: 0.9937 - val_loss: 1.3990 - val_precision: 0.7515 - val_recall: 0.7482
# Epoch 41/50
# 144/144 [==============================] - 20s 140ms/step - loss: 0.0120 - precision: 0.9959 - recall: 0.9959 - val_loss: 1.8111 - val_precision: 0.7149 - val_recall: 0.7132
# Epoch 42/50
# 144/144 [==============================] - 20s 139ms/step - loss: 0.0091 - precision: 0.9963 - recall: 0.9963 - val_loss: 1.9328 - val_precision: 0.7193 - val_recall: 0.7161
# Epoch 43/50
# 144/144 [==============================] - 20s 140ms/step - loss: 0.0080 - precision: 0.9976 - recall: 0.9976 - val_loss: 1.5544 - val_precision: 0.7438 - val_recall: 0.7413
# Epoch 44/50
# 144/144 [==============================] - 20s 140ms/step - loss: 0.0082 - precision: 0.9967 - recall: 0.9965 - val_loss: 1.1219 - val_precision: 0.8001 - val_recall: 0.7969
# Epoch 45/50
# 144/144 [==============================] - 20s 139ms/step - loss: 0.0092 - precision: 0.9963 - recall: 0.9963 - val_loss: 1.4295 - val_precision: 0.7616 - val_recall: 0.7590
# Epoch 46/50
# 144/144 [==============================] - 20s 139ms/step - loss: 0.0055 - precision: 0.9983 - recall: 0.9983 - val_loss: 1.3781 - val_precision: 0.7645 - val_recall: 0.7615
# Epoch 47/50
# 144/144 [==============================] - 20s 140ms/step - loss: 0.0071 - precision: 0.9976 - recall: 0.9970 - val_loss: 1.7513 - val_precision: 0.7134 - val_recall: 0.7102
# Epoch 48/50
# 144/144 [==============================] - 20s 140ms/step - loss: 0.0054 - precision: 0.9985 - recall: 0.9983 - val_loss: 1.3674 - val_precision: 0.7705 - val_recall: 0.7679
# Epoch 49/50
# 144/144 [==============================] - 20s 140ms/step - loss: 0.0048 - precision: 0.9985 - recall: 0.9985 - val_loss: 1.6551 - val_precision: 0.7295 - val_recall: 0.7270
# Epoch 50/50
# 144/144 [==============================] - 20s 139ms/step - loss: 0.0034 - precision: 0.9985 - recall: 0.9983 - val_loss: 1.2743 - val_precision: 0.7717 - val_recall: 0.7679

# %% [markdown]
# ### Visualize Training Results

# %%
plt.plot(model_history.history['recall'], label='recall')
plt.plot(model_history.history['val_recall'], label = 'val_recall')
plt.xlabel('Epoch')
plt.ylabel('recall')
plt.ylim([0, 1])
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ### Save the Model

# %%
#model.save('F:\\MRI_class\\data\\Alzheimer_s Dataset_30percentVal\\ResNet50_LR10-5_augm_Oversample\\')
#model.save('F:\\MRI_class\\data\\Alzheimer_s Dataset_30percentVal\\ResNet50_LR10-5_augm_Oversample\\h5\\model_1.h5')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 53). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: F:\MRI_class\data\Alzheimer_s Dataset_30percentVal\ResNet50_LR10-5_augm_Oversample\assets
# INFO:tensorflow:Assets written to: F:\MRI_class\data\Alzheimer_s Dataset_30percentVal\ResNet50_LR10-5_augm_Oversample\assets

# %% [markdown]
# ### Load a Testset

# %%
oasis_img_temp, oasis_label_temp = load_oasis_set_win()
# Out:
# Image Array Shape: (231, 208, 176, 3)
#
# Image Count: 231
#
# labels: [0. 1. 2. 3.]
#
# Class Counts:
#       ID
# CDR
# 0.0  131
# 1.0   70
# 2.0   28
# 3.0    2

# %% [markdown]
# ### Get only classes 0, 1 and 2 of the Testset

# %%
oasis_images = []
oasis_labels = []
for image,label in zip(oasis_img_temp,oasis_label_temp):
    if int(label) == 3:
        continue
    if int(label) == 0:
        #image = image/255
        oasis_images.append(cv2.flip(image,0))
        oasis_labels.append([1,0,0])
    if int(label) == 1:
        #image = image/255
        oasis_images.append(cv2.flip(image,0))
        oasis_labels.append([0,1,0])
    if int(label) == 2:
        #image = image/255
        oasis_images.append(cv2.flip(image,0))
        oasis_labels.append([0,0,1])

oasis_images = np.array(oasis_images)
oasis_labels = np.array(oasis_labels)

# %%
plt.imshow(oasis_images[0].astype("uint8"))

# %% [markdown]
# ### Perform a Prediction on the Testset and Visualize the Results

# %%
oasis_pred = model.predict(oasis_images, batch_size=1)
# Out:
# 229/229 [==============================] - 3s 9ms/step

# %%
precision_recall_multiclass(oasis_pred,oasis_labels,["healthy","veryMildAD","mildAD"])
# Out:
# -----Recalls-----
# healthy Recall: 0.7022900763358778
# veryMildAD Recall: 0.5428571428571428
# mildAD Recall: 0.5357142857142857
# -------#####-------
#
#
# -----Precisions-----
# healthy Precision: 0.7540983606557377
# veryMildAD Precision: 0.6440677966101694
# mildAD Precision: 0.3125
# -------#####-------
#
#
# -----Accuracy-----
# healthy Accuracy: 0.7540983606557377
# veryMildAD Accuracy: 0.6440677966101694
# mildAD Accuracy: 0.3125
# -------#####-------
#
#
# -----Macro Recall and Precisions-----
# Macro recall: 0.5936205016357688
# Macro recall: 0.5702220524219691
# ------------#####------------
