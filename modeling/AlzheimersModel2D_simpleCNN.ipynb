# %%
#load all packages

# base packages
import keras
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2

# tensorflow and keras
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.utils import image_dataset_from_directory
from keras import metrics

# sklearn
from sklearn.utils import shuffle
from sklearn.metrics import recall_score, precision_score, confusion_matrix

# self-build procedures
from roc_multiclass import roc_multiclass
from precision_recall_multiclass import precision_recall_multiclass
from load_oasis_set import load_oasis_set
from load_oasis_set_win import load_oasis_set_win
from DataGenerator import DataGenerator

# %% [markdown]
# ### Load Train Data and oversample

# %%
# load dataset from drive
#PATH = "/Users/josealbertodiazsalas/Documents/Alzheimer_s Dataset/train"
PATH = "F:\\MRI_class\\data\\Alzheimer_s Dataset_30percentVal\\train"
IMAGE_SIZE = (208, 176)
train_ds = image_dataset_from_directory(
                                        PATH, 
                                        seed=10, 
                                        shuffle=False,              #<---
                                        image_size=IMAGE_SIZE, 
                                        batch_size=32
                                        )
                                        
# one hot encode the labels to fit into the cnn layers
train_ds = train_ds.map(lambda x, y: (x, tf.one_hot(y, depth=3)))
# Out:
# Found 3040 files belonging to 3 classes.

# %% [markdown]
# ### Deconstuct Train Dataset and Prepare for Oversampling

# %%
# seperation of validation set
# !!! these sets are not shuffled !!!

train_big = train_ds
X1_train_big = []
y1_train_big = []
X2_train_big = []
y2_train_big = []
X3_train_big = []
y3_train_big = []


for img, label in train_ds.unbatch():
    if label.numpy()[0] == 1:
        X1_train_big.append(img.numpy())
        y1_train_big.append(label.numpy())

    if label.numpy()[1] == 1:
        X2_train_big.append(img.numpy())
        y2_train_big.append(label.numpy())

    if label.numpy()[2] == 1:
        X3_train_big.append(img.numpy())
        y3_train_big.append(label.numpy())

# %% [markdown]
# ### Oversampling
# Fill classes to match class 0 (Healthy)

# %%
# create dataset for class 1 -NO oversampling- (healthy)
X1_train_big = np.array(X1_train_big)
y1_train_big = np.array(y1_train_big)

# %%
# oversampling for class 2 (very mild)
randomPicksIdx = [np.random.choice(len(X2_train_big)) for i in range(len(X1_train_big) - len(X2_train_big))]        # images are randomly picked

for i in randomPicksIdx:
    X2_train_big.append(X2_train_big[i])
    y2_train_big.append(y2_train_big[i])

X2_train_big = np.array(X2_train_big)
y2_train_big = np.array(y2_train_big)

# %%
# oversampling for class 3 (mild)
randomPicksIdx = [np.random.choice(len(X3_train_big)) for i in range(len(X1_train_big) - len(X3_train_big))]

for i in randomPicksIdx:
    X3_train_big.append(X3_train_big[i])
    y3_train_big.append(y3_train_big[i])

X3_train_big = np.array(X3_train_big)
y3_train_big = np.array(y3_train_big)

# %% [markdown]
# ### Construct full Dataset Tensor for Training

# %%
# combine all data sets
X_train_fullset = np.concatenate((X1_train_big,X2_train_big,X3_train_big), axis=0)
y_train_fullset = np.concatenate((y1_train_big,y2_train_big,y3_train_big), axis=0)

# %%
# shuffle the whole set
X_train_temp, y_train_temp = shuffle(X_train_fullset, y_train_fullset, random_state=10)

# %%
# finally create tensor dataset
data_generator = DataGenerator(X_train_temp, y_train_temp, batch_size = 32)         # generator is used to load data in batches

train_fullTensor = tf.data.Dataset.from_generator(
                                            data_generator,
                                            output_signature=(tf.TensorSpec(shape=(None, 208, 176, 3), dtype=tf.float32), tf.TensorSpec(shape=(None, 3), dtype=tf.float32))
                                            )

# %% [markdown]
# ### Load Validation Set

# %%
# load validation dataset from drive
# set for training
#PATH = "/Users/josealbertodiazsalas/Documents/Alzheimer_s Dataset/train"
PATH = "F:\\MRI_class\\data\\Alzheimer_s Dataset_30percentVal\\validation"
IMAGE_SIZE = (208, 176)
val_ds = image_dataset_from_directory(
                                        PATH, 
                                        seed=10, 
                                        shuffle=True, 
                                        image_size=IMAGE_SIZE, 
                                        batch_size=32
                                        )

# one hot encode the labels to fit into the cnn layers
val_fullTensor = val_ds.map(lambda x, y: (x, tf.one_hot(y, depth=3)))
# Out:
# Found 2029 files belonging to 3 classes.

# %% [markdown]
# ### Check Images for Integrity

# %%
# plot some example images from loaded set
plt.figure(figsize=(10, 10))
for images, labels in train_fullTensor.take(1):
  for i in range(3):
    ax = plt.subplot(1, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"), cmap="gray")
    plt.title([labels[i].numpy()][0])
    plt.axis("off")
# Out:
# f:\alzheimer-classification\envwin\lib\site-packages\matplotlib\text.py:1223: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %% [markdown]
# # Creating CNN Architecture
# ### First Creating Augmentation Module

# %%
with tf.device("/gpu:0"):
    data_augmentation = keras.Sequential([
        layers.InputLayer(input_shape=(208, 176, 3)),
        layers.Lambda(lambda x: tf.image.resize(x, (208, 176))),
        layers.Lambda(lambda x: tf.image.random_contrast(x,0.6,1)),
        layers.Lambda(lambda x: tf.image.random_brightness(x,0.3)),             #<--- delta value depends on image range. if 0-1 delta should be between 0-1. if 0-255 delta should be between 0-255
        layers.RandomRotation(0.01),
        layers.RandomFlip(mode="horizontal"),
        layers.RandomZoom(0.03),
        #layers.RandomBrightness((0.2), value_range=(0,255)),
        #layers.Resizing(208, 176),
        #layers.RandomContrast((0.2))
])

# %% [markdown]
# ### Check Images for proper Augmentation

# %%
with tf.device("/gpu:0"):
    plt.figure(figsize=(10, 10))
    for images, labels in train_fullTensor.take(1):
        for i in range(3):
            ax = plt.subplot(1, 3, i + 1)
            img = data_augmentation(images/255)             # divided by 255 (normalization) since augmentation depends on normalization which is 
            plt.imshow(img[i].numpy(), cmap="gray")         # a specific layer in the CNN and not part of augmentation
            plt.title([labels[i].numpy()][0])
            plt.axis("off")
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ### Building the complete CNN

# %%
#iniziating model architecture
model = models.Sequential()
model.add(layers.InputLayer(input_shape=(208, 176, 3)))
model.add(layers.Rescaling(1/255))
model.add(data_augmentation)
model.add(layers.Conv2D(100, (3, 3), padding='same', activation='relu'))
model.add(layers.Conv2D(100, (3, 3), padding='same', activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(50, (3, 3), activation='relu'))
model.add(layers.Conv2D(50, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(25, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

#add dense layes to conv layers
model.add(layers.Flatten())
model.add(layers.Dense(50, activation='relu'))
model.add(layers.Dropout(rate=0.3))
model.add(layers.Dense(25, activation='relu'))
model.add(layers.Dense(3, activation="softmax"))

# %% [markdown]
# ### Defining the Optimizer

# %%
# Defining optimizer and learning rate
lr_schedule = tf.keras.optimizers.schedules.InverseTimeDecay(
    0.0001,
    decay_steps=10000,
    decay_rate=1,
    staircase=False)
optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule, name='Adam')

# %% [markdown]
# ### Compile the CNN Architecture

# %%
# Freeze the the behavior of that model. If any trainable value changes, compile() must be called again
keras.backend.clear_session()
model.compile(optimizer=optimizer,
    loss="CategoricalCrossentropy",
    metrics=[metrics.Precision(), metrics.Recall()])

# %% [markdown]
# ### Train the Model
# You can chose the save the model iterativly at every checkpoint by including the lines

# %%
# Saving model parameters and weights per epoch
#checkpoint_filepath = 'F:\\MRI_class\\data\\Alzheimer_s Dataset_20percentVal\\SimpleCNN_lr10-4\\checkpoint_model.epoch{epoch:02d}-recall{val_recall:.2f}.hdf5'
#model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_filepath, save_weights_only=False, monitor='val_recall', mode='max',
#save_best_only=True)

# Model training. Model weights are saved at the end of every epoch, if it's the best seen so far
with tf.device("/gpu:0"):
    tf.random.set_seed(10)
    model_history = model.fit(x=train_fullTensor,
                        validation_data=val_fullTensor,
                        epochs=50, 
                        shuffle=True
                        #callbacks=[model_checkpoint_callback]
                        )
# Out:
# Epoch 1/50
# 144/144 [==============================] - 23s 131ms/step - loss: 1.0985 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.0999 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/50
# 144/144 [==============================] - 15s 104ms/step - loss: 1.0662 - precision: 0.5678 - recall: 0.0337 - val_loss: 1.0621 - val_precision: 0.5018 - val_recall: 0.2100
# Epoch 3/50
# 144/144 [==============================] - 15s 104ms/step - loss: 0.9797 - precision: 0.6395 - recall: 0.2265 - val_loss: 1.0581 - val_precision: 0.4990 - val_recall: 0.3568
# Epoch 4/50
# 144/144 [==============================] - 15s 104ms/step - loss: 0.9188 - precision: 0.6437 - recall: 0.3322 - val_loss: 0.9938 - val_precision: 0.5324 - val_recall: 0.3760
# Epoch 5/50
# 144/144 [==============================] - 15s 103ms/step - loss: 0.8710 - precision: 0.6727 - recall: 0.3933 - val_loss: 0.9074 - val_precision: 0.5894 - val_recall: 0.4648
# Epoch 6/50
# 144/144 [==============================] - 15s 104ms/step - loss: 0.8330 - precision: 0.6827 - recall: 0.4434 - val_loss: 0.8947 - val_precision: 0.6212 - val_recall: 0.4179
# Epoch 7/50
# 144/144 [==============================] - 15s 104ms/step - loss: 0.7956 - precision: 0.7065 - recall: 0.4960 - val_loss: 0.8528 - val_precision: 0.6476 - val_recall: 0.4510
# Epoch 8/50
# 144/144 [==============================] - 15s 103ms/step - loss: 0.7617 - precision: 0.7215 - recall: 0.5220 - val_loss: 0.8150 - val_precision: 0.6608 - val_recall: 0.5347
# Epoch 9/50
# 144/144 [==============================] - 15s 104ms/step - loss: 0.7290 - precision: 0.7292 - recall: 0.5590 - val_loss: 0.8226 - val_precision: 0.6530 - val_recall: 0.4805
# Epoch 10/50
# 144/144 [==============================] - 15s 105ms/step - loss: 0.6967 - precision: 0.7406 - recall: 0.5802 - val_loss: 0.8349 - val_precision: 0.6433 - val_recall: 0.5530
# Epoch 11/50
# 144/144 [==============================] - 15s 105ms/step - loss: 0.6728 - precision: 0.7508 - recall: 0.6052 - val_loss: 0.7233 - val_precision: 0.6970 - val_recall: 0.5964
# Epoch 12/50
# 144/144 [==============================] - 15s 104ms/step - loss: 0.6426 - precision: 0.7672 - recall: 0.6261 - val_loss: 0.7463 - val_precision: 0.6931 - val_recall: 0.5909
# Epoch 13/50
# 144/144 [==============================] - 15s 104ms/step - loss: 0.6126 - precision: 0.7762 - recall: 0.6365 - val_loss: 0.7194 - val_precision: 0.7033 - val_recall: 0.5840
# Epoch 14/50
# 144/144 [==============================] - 15s 104ms/step - loss: 0.6113 - precision: 0.7781 - recall: 0.6486 - val_loss: 0.6739 - val_precision: 0.7272 - val_recall: 0.6294
# Epoch 15/50
# 144/144 [==============================] - 15s 105ms/step - loss: 0.5767 - precision: 0.7815 - recall: 0.6632 - val_loss: 0.6340 - val_precision: 0.7476 - val_recall: 0.6555
# Epoch 16/50
# 144/144 [==============================] - 15s 105ms/step - loss: 0.5606 - precision: 0.7959 - recall: 0.6840 - val_loss: 0.7018 - val_precision: 0.7123 - val_recall: 0.6417
# Epoch 17/50
# 144/144 [==============================] - 15s 105ms/step - loss: 0.5408 - precision: 0.8073 - recall: 0.7003 - val_loss: 0.6385 - val_precision: 0.7459 - val_recall: 0.6772
# Epoch 18/50
# 144/144 [==============================] - 15s 104ms/step - loss: 0.5251 - precision: 0.8099 - recall: 0.7086 - val_loss: 0.5695 - val_precision: 0.7879 - val_recall: 0.6939
# Epoch 19/50
# 144/144 [==============================] - 15s 105ms/step - loss: 0.5202 - precision: 0.8126 - recall: 0.7051 - val_loss: 0.6481 - val_precision: 0.7416 - val_recall: 0.6747
# Epoch 20/50
# 144/144 [==============================] - 15s 105ms/step - loss: 0.4927 - precision: 0.8229 - recall: 0.7197 - val_loss: 0.6396 - val_precision: 0.7439 - val_recall: 0.6959
# Epoch 21/50
# 144/144 [==============================] - 15s 105ms/step - loss: 0.4926 - precision: 0.8154 - recall: 0.7155 - val_loss: 0.5169 - val_precision: 0.7979 - val_recall: 0.7063
# Epoch 22/50
# 144/144 [==============================] - 15s 104ms/step - loss: 0.4640 - precision: 0.8277 - recall: 0.7394 - val_loss: 0.4736 - val_precision: 0.8007 - val_recall: 0.7565
# Epoch 23/50
# 144/144 [==============================] - 15s 102ms/step - loss: 0.4400 - precision: 0.8409 - recall: 0.7642 - val_loss: 0.4555 - val_precision: 0.8038 - val_recall: 0.7472
# Epoch 24/50
# 144/144 [==============================] - 15s 102ms/step - loss: 0.4450 - precision: 0.8421 - recall: 0.7574 - val_loss: 0.5494 - val_precision: 0.7808 - val_recall: 0.7215
# Epoch 25/50
# 144/144 [==============================] - 15s 101ms/step - loss: 0.4026 - precision: 0.8514 - recall: 0.7765 - val_loss: 0.4642 - val_precision: 0.8153 - val_recall: 0.7595
# Epoch 26/50
# 144/144 [==============================] - 15s 101ms/step - loss: 0.4183 - precision: 0.8445 - recall: 0.7739 - val_loss: 0.5433 - val_precision: 0.7912 - val_recall: 0.7097
# Epoch 27/50
# 144/144 [==============================] - 15s 101ms/step - loss: 0.4059 - precision: 0.8484 - recall: 0.7765 - val_loss: 0.4617 - val_precision: 0.8091 - val_recall: 0.7560
# Epoch 28/50
# 144/144 [==============================] - 15s 101ms/step - loss: 0.3949 - precision: 0.8533 - recall: 0.7820 - val_loss: 0.4591 - val_precision: 0.8144 - val_recall: 0.7634
# Epoch 29/50
# 144/144 [==============================] - 15s 101ms/step - loss: 0.3799 - precision: 0.8627 - recall: 0.7952 - val_loss: 0.4151 - val_precision: 0.8307 - val_recall: 0.7787
# Epoch 30/50
# 144/144 [==============================] - 15s 101ms/step - loss: 0.3724 - precision: 0.8626 - recall: 0.7935 - val_loss: 0.4220 - val_precision: 0.8208 - val_recall: 0.7767
# Epoch 31/50
# 144/144 [==============================] - 15s 101ms/step - loss: 0.3765 - precision: 0.8576 - recall: 0.7911 - val_loss: 0.4239 - val_precision: 0.8265 - val_recall: 0.7960
# Epoch 32/50
# 144/144 [==============================] - 15s 101ms/step - loss: 0.3625 - precision: 0.8547 - recall: 0.7972 - val_loss: 0.4836 - val_precision: 0.8152 - val_recall: 0.7674
# Epoch 33/50
# 144/144 [==============================] - 15s 101ms/step - loss: 0.3465 - precision: 0.8804 - recall: 0.8219 - val_loss: 0.3964 - val_precision: 0.8439 - val_recall: 0.7994
# Epoch 34/50
# 144/144 [==============================] - 15s 101ms/step - loss: 0.3430 - precision: 0.8684 - recall: 0.8111 - val_loss: 0.4170 - val_precision: 0.8342 - val_recall: 0.8083
# Epoch 35/50
# 144/144 [==============================] - 15s 101ms/step - loss: 0.3437 - precision: 0.8719 - recall: 0.8143 - val_loss: 0.4216 - val_precision: 0.8409 - val_recall: 0.7787
# Epoch 36/50
# 144/144 [==============================] - 15s 101ms/step - loss: 0.3380 - precision: 0.8739 - recall: 0.8174 - val_loss: 0.3547 - val_precision: 0.8590 - val_recall: 0.8255
# Epoch 37/50
# 144/144 [==============================] - 15s 101ms/step - loss: 0.3328 - precision: 0.8721 - recall: 0.8217 - val_loss: 0.3737 - val_precision: 0.8514 - val_recall: 0.8162
# Epoch 38/50
# 144/144 [==============================] - 15s 102ms/step - loss: 0.3295 - precision: 0.8724 - recall: 0.8221 - val_loss: 0.3632 - val_precision: 0.8621 - val_recall: 0.8260
# Epoch 39/50
# 144/144 [==============================] - 15s 101ms/step - loss: 0.3093 - precision: 0.8796 - recall: 0.8280 - val_loss: 0.3778 - val_precision: 0.8494 - val_recall: 0.8226
# Epoch 40/50
# 144/144 [==============================] - 15s 101ms/step - loss: 0.3148 - precision: 0.8824 - recall: 0.8330 - val_loss: 0.3623 - val_precision: 0.8601 - val_recall: 0.8300
# Epoch 41/50
# 144/144 [==============================] - 15s 102ms/step - loss: 0.3210 - precision: 0.8739 - recall: 0.8219 - val_loss: 0.3531 - val_precision: 0.8526 - val_recall: 0.8181
# Epoch 42/50
# 144/144 [==============================] - 15s 102ms/step - loss: 0.2970 - precision: 0.8892 - recall: 0.8434 - val_loss: 0.3810 - val_precision: 0.8587 - val_recall: 0.8329
# Epoch 43/50
# 144/144 [==============================] - 15s 102ms/step - loss: 0.2997 - precision: 0.8867 - recall: 0.8415 - val_loss: 0.3485 - val_precision: 0.8641 - val_recall: 0.8339
# Epoch 44/50
# 144/144 [==============================] - 15s 102ms/step - loss: 0.2947 - precision: 0.8839 - recall: 0.8367 - val_loss: 0.3437 - val_precision: 0.8599 - val_recall: 0.8349
# Epoch 45/50
# 144/144 [==============================] - 15s 102ms/step - loss: 0.2896 - precision: 0.8925 - recall: 0.8473 - val_loss: 0.3473 - val_precision: 0.8596 - val_recall: 0.8452
# Epoch 46/50
# 144/144 [==============================] - 15s 102ms/step - loss: 0.2900 - precision: 0.8929 - recall: 0.8506 - val_loss: 0.3420 - val_precision: 0.8692 - val_recall: 0.8448
# Epoch 47/50
# 144/144 [==============================] - 15s 102ms/step - loss: 0.2708 - precision: 0.9010 - recall: 0.8534 - val_loss: 0.3423 - val_precision: 0.8559 - val_recall: 0.8344
# Epoch 48/50
# 144/144 [==============================] - 15s 102ms/step - loss: 0.2827 - precision: 0.8903 - recall: 0.8458 - val_loss: 0.4156 - val_precision: 0.8468 - val_recall: 0.8255
# Epoch 49/50
# 144/144 [==============================] - 15s 105ms/step - loss: 0.2854 - precision: 0.8886 - recall: 0.8404 - val_loss: 0.3097 - val_precision: 0.8707 - val_recall: 0.8526
# Epoch 50/50
# 144/144 [==============================] - 15s 104ms/step - loss: 0.2779 - precision: 0.8901 - recall: 0.8439 - val_loss: 0.3133 - val_precision: 0.8744 - val_recall: 0.8541

# %% [markdown]
# ### Visualize Training Results

# %%
plt.plot(model_history.history['recall'], label='recall')
plt.plot(model_history.history['val_recall'], label = 'val_recall')
plt.xlabel('Epoch')
plt.ylabel('recall')
plt.ylim([0, 1])
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ### Save the Model

# %%
model.save('F:\\MRI_class\\data\\Alzheimer_s Dataset_30percentVal\\simple_LR10-4_augm_Oversample\\')
model.save('F:\\MRI_class\\data\\Alzheimer_s Dataset_30percentVal\\simple_LR10-4_augm_Oversample\\h5\\model_1.h5')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: F:\MRI_class\data\Alzheimer_s Dataset_30percentVal\simple_LR10-4_augm_Oversample\assets
# INFO:tensorflow:Assets written to: F:\MRI_class\data\Alzheimer_s Dataset_30percentVal\simple_LR10-4_augm_Oversample\assets

# %% [markdown]
# ### Load a Testset

# %%
oasis_img_temp, oasis_label_temp = load_oasis_set_win()
# Out:
# Image Array Shape: (231, 208, 176, 3)
#
# Image Count: 231
#
# labels: [0. 1. 2. 3.]
#
# Class Counts:
#       ID
# CDR
# 0.0  131
# 1.0   70
# 2.0   28
# 3.0    2

# %% [markdown]
# ### Get only classes 0, 1 and 2 of the Testset

# %%
oasis_images = []
oasis_labels = []
for image,label in zip(oasis_img_temp,oasis_label_temp):
    if int(label) == 3:
        continue
    if int(label) == 0:
        
        oasis_images.append(cv2.flip(image,0))
        oasis_labels.append([1,0,0])
    if int(label) == 1:
        
        oasis_images.append(cv2.flip(image,0))
        oasis_labels.append([0,1,0])
    if int(label) == 2:
        
        oasis_images.append(cv2.flip(image,0))
        oasis_labels.append([0,0,1])

oasis_images = np.array(oasis_images)
oasis_labels = np.array(oasis_labels)

# %%
plt.imshow(oasis_images[0].astype("uint8"))

# %% [markdown]
# ### Perform a Prediction on the Testset and Visualize the Results

# %%
oasis_pred = model.predict(oasis_images, batch_size=1)
# Out:
# 229/229 [==============================] - 1s 2ms/step

# %%
precision_recall_multiclass(oasis_pred,oasis_labels,["healthy","veryMildAD","mildAD"])
# Out:
# -----Recalls-----
# healthy Recall: 0.8549618320610687
# veryMildAD Recall: 0.9142857142857143
# mildAD Recall: 1.0
# -------#####-------
#
#
# -----Precisions-----
# healthy Precision: 0.9491525423728814
# veryMildAD Precision: 0.7804878048780488
# mildAD Precision: 0.9655172413793104
# -------#####-------
#
#
# -----Precisions-----
# healthy Precision: 0.9491525423728814
# veryMildAD Precision: 0.7804878048780488
# mildAD Precision: 0.9655172413793104
# -------#####-------
#
#
# -----Macro Recall and Precisions-----
# Macro recall: 0.9230825154489276
# Macro recall: 0.8983858628767468
# ------------#####------------
